# %% [markdown]
# # New Service subscription for all Accounts
#
# This is an automation of the method described in the notebook `activate_service.ipynb`.

# %% [markdown]
# ### Init

# %%
import activate_service_functions as asf

# %% [markdown]
# ### Get the Accounts
#
# Note: those are organization accounts, not user accounts within an organization

# %%
accounts = asf.get_accounts()

print(f"{len(accounts['accounts']['account'])} accounts found")
# Out:
# 794 accounts found

# %%
# Display a specific account
print(accounts["accounts"]["account"][1])
# Out:
# {'id': '7', 'created_at': '2024-08-14T09:07:14-04:00', 'updated_at': '2024-08-14T09:07:14-04:00', 'state': 'approved', 'org_name': 'gmoutier@redhat.com', 'extra_fields': None, 'monthly_billing_enabled': 'true', 'monthly_charging_enabled': 'true', 'credit_card_stored': 'false', 'plans': {'plan': [{'@default': 'true', 'id': '23', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '10'}, {'@default': 'true', 'id': '39', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '18'}, {'@default': 'true', 'id': '37', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '17'}, {'@default': 'true', 'id': '35', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '16'}, {'@default': 'true', 'id': '33', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '15'}, {'@default': 'true', 'id': '31', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '14'}, {'@default': 'true', 'id': '29', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '13'}, {'@default': 'true', 'id': '27', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '12'}, {'@default': 'true', 'id': '25', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '11'}, {'@default': 'true', 'id': '6', 'name': 'Default', 'type': 'account_plan', 'state': 'hidden', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0'}, {'@default': 'true', 'id': '21', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '9'}, {'@default': 'true', 'id': '19', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '8'}, {'@default': 'true', 'id': '17', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '7'}, {'@default': 'true', 'id': '15', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '6'}, {'@default': 'true', 'id': '11', 'name': 'Default', 'type': 'service_plan', 'state': 'published', 'approval_required': 'false', 'setup_fee': '0.0', 'cost_per_month': '0.0', 'trial_period_days': None, 'cancellation_period': '0', 'service_id': '5' ...

# %% [markdown]
# ### Get the Services

# %%
services = asf.get_services()

print(f"{len(services['services']['service'])} services found")
# Out:
# 16 services found

# %%
# Display available Services    
for service in services["services"]["service"]:
    print(f"Service id: {service['id']}")
    print(f"Service name: {service['name']}")
    print("---")
# Out:
# Service id: 3
# Service name: Granite-8B-Code-Instruct
# ---
# Service id: 4
# Service name: Mistral-7B-Instruct-v0.3
# ---
# Service id: 5
# Service name: Nomic-embed-text-v1.5
# ---
# Service id: 6
# Service name: Granite-3.1-8B-Instruct
# ---
# Service id: 7
# Service name: Docling
# ---
# Service id: 8
# Service name: Granite-8B-Lab-v1
# ---
# Service id: 9
# Service name: Granite-Embedding-278m-multilingual
# ---
# Service id: 10
# Service name: DeepSeek-R1-Distill-Qwen-14B
# ---
# Service id: 11
# Service name: StableDiffusion-XL
# ---
# Service id: 12
# Service name: DeepSeek-R1-Distill-Qwen-14B-W4A16
# ---
# Service id: 13
# Service name: Granite-3.1-8B-Instruct-W4A16
# ---
# Service id: 14
# Service name: Llama-3.1-8B-Instruct
# ---
# Service id: 15
# Service name: Granite Guardian 3.1 2B
# ---
# Service id: 16
# Service name: Stable Diffusion Safety Checker
# ---
# Service id: 17
# Service name: Mixtral-8x7B-Instruct-v0.1
# ---
# Service id: 18
# Service name: Phi-4
# ---

# %%
# Set the Service to use in the next requests
service_id = 18 # Granite Guardian 3.1 2B

# %% [markdown]
# ### Get the Service Plans
#
# We need the Service Plan id to use when creating a dummy application.

# %%
plans = asf.get_service_plans()

print(f"{len(plans['plans']['plan'])} application plans found")
# Out:
# 16 application plans found

# %%
# Display available Plans
for plan in plans["plans"]["plan"]:
    print(f"Plan id: {plan['id']}")
    print(f"Plan name: {plan['name']}")
    print(f"Service id: {plan['service_id']}")
    print("---")
# Out:
# Plan id: 24
# Plan name: Standard Plan
# Service id: 10
# ---
# Plan id: 40
# Plan name: Standard
# Service id: 18
# ---
# Plan id: 38
# Plan name: Standard
# Service id: 17
# ---
# Plan id: 36
# Plan name: Standard
# Service id: 16
# ---
# Plan id: 34
# Plan name: Standard
# Service id: 15
# ---
# Plan id: 32
# Plan name: Standard
# Service id: 14
# ---
# Plan id: 30
# Plan name: Standard
# Service id: 13
# ---
# Plan id: 28
# Plan name: Standard
# Service id: 12
# ---
# Plan id: 26
# Plan name: Standard Plan
# Service id: 11
# ---
# Plan id: 22
# Plan name: Standard Plan
# Service id: 9
# ---
# Plan id: 20
# Plan name: Standard Plan
# Service id: 8
# ---
# Plan id: 18
# Plan name: Standard Plan
# Service id: 7
# ---
# Plan id: 16
# Plan name: Standard Plan
# Service id: 6
# ---
# Plan id: 14
# Plan name: Standard Plan
# Service id: 3
# ---
# Plan id: 13
# Plan name: Standard Plan
# Service id: 4
# ---
# Plan id: 12
# Plan name: Standard Plan
# Service id: 5
# ---

# %%
# Set the Plan to use in the next requests
plan_id = asf.get_service_plan_by_service_id(plans, service_id)

print(f"Plan id: {plan_id}")
# Out:
# Plan id: 40

# %% [markdown]
# ### Subscribe all accounts to selected Service/Plan

# %%
print(f"plan_id: {plan_id}")
for account in accounts["accounts"]["account"]:
    try:
        account_id = int(account["id"])
        application_id = int(asf.create_dummy_application(account_id, plan_id))
        response = asf.delete_application(account_id, application_id)
        if response.status_code == 200:
            print(f"Account {account_id} subscribed!")
        else:
            print(f"Error deleting application {application_id} for account {account_id}")
            print(response.content)
    except Exception as e:
        print(f"Error creating application for account {account_id}")
        print(e)
        continue
# Out:
# plan_id: 40
# Account 6 subscribed!
# Account 7 subscribed!
# Account 8 subscribed!
# Account 9 subscribed!
# Account 10 subscribed!
# Account 11 subscribed!
# Account 12 subscribed!
# Account 13 subscribed!
# Account 14 subscribed!
# Account 15 subscribed!
# Account 16 subscribed!
# Account 17 subscribed!
# Account 18 subscribed!
# Account 19 subscribed!
# Account 20 subscribed!
# Account 21 subscribed!
# Account 22 subscribed!
# Account 23 subscribed!
# Account 24 subscribed!
# Account 25 subscribed!
# Account 26 subscribed!
# Account 27 subscribed!
# Account 28 subscribed!
# Account 29 subscribed!
# Account 30 subscribed!
# Account 31 subscribed!
# Account 32 subscribed!
# Account 33 subscribed!
# Account 34 subscribed!
# Account 35 subscribed!
# Account 36 subscribed!
# Account 37 subscribed!
# Account 38 subscribed!
# Account 39 subscribed!
# Account 40 subscribed!
# Account 41 subscribed!
# Account 42 subscribed!
# Account 43 subscribed!
# Account 44 subscribed!
# Account 45 subscribed!
# Account 46 subscribed!
# Account 47 subscribed!
# Account 48 subscribed!
# Account 49 subscribed!
# Account 50 subscribed!
# Account 52 subscribed!
# Account 53 subscribed!
# Account 54 subscribed!
# Account 55 subscribed!
# Account 56 subscribed!
# Account 57 subscribed!
# Account 58 subscribed!
# Account 59 subscribed!
# Account 60 subscribed!
# Account 61 subscribed!
# Account 62 subscribed!
# Account 63 subscribed!
# Account 64 subscribed!
# Account 65 subscribed!
# Account 66 subscribed!
# Account 67 subscribed!
# Account 68 subscribed!
# Account 69 subscribed!
# Account 70 subscribed!
# Account 71 subscribed!
# Account 72 subscribed!
# Account 73 subscribed!
# Account 74 subscribed!
# Account 75 subscribed!
# Account 76 subscribed!
# Account 77 subscribed!
# Account 78 subscribed!
# Account 79 subscribed!
# Account 80 subscribed!
# Account 81 subscribed!
# Account 82 subscribed!
# Account 83 subscribed!
# Account 84 subscribed!
# Account 85 subscribed!
# Account 86 subscribed!
# Account 87 subscribed!
# Account 88 subscribed!
# Account 89 subscribed!
# Account 90 subscribed!
# Account 91 subscribed!
# Account 92 subscribed!
# Account 93 subscribed!
# Account 94 subscribed!
# Account 95 subscribed!
# Account 96 subscribed!
# Account 97 subscribed!
# Account 98 subscribed!
# Account 99 subscribed!
# Account 100 subscribed!
# Account 101 subscribed!
# Account 102 subscribed!
# Account 103 subscribed!
# Account 104 subscribed!
# Account 105 subscribed!
# Account 106 subscribed!
# Account 107 subscribed!
# Account 108 subscribed!
# Account 109 subscribed!
# Account 110 subscribed!
# Account 111 subscribed!
# Account 112 subscribed!
# Account 113 subscribed!
# Account 114 subscribed!
# Account 115 subscribed!
# Account 116 subscribed!
# Account 117 subscribed!
# Account 118 subscribed!
# Account 119 subscribed!
# Account 120 subscribed!
# Account 121 subscribed!
# Account 122 subscribed!
# Account 123 subscribed!
# Account 124 subscribed!
# Account 125 subscribed!
# Account 126 subscribed!
# Account 127 subscribed!
# Account 128 subscribed!
# Account 129 subscribed!
# Account 130 subscribed!
# Account 131 subscribed!
# Account 132 subscribed!
# Account 133 subscribed!
# Account 134 subscribed!
# Account 135 subscribed!
# Account 136 subscribed!
# Account 137 subscribed!
# Account 138 subscribed!
# Account 139 subscribed!
# Account 140 subscribed!
# Account 141 subscribed!
# Account 142 subscribed!
# Account 143 subscribed!
# Account 144 subscribed!
# Account 145 subscribed!
# Account 146 subscribed!
# Account 147 subscribed!
# Account 148 subscribed!
# Account 149 subscribed!
# Account 150 subscribed!
# Account 151 subscribed!
# Account 152 subscribed!
# Account 153 subscribed!
# Account 154 subscribed!
# Account 155 subscribed!
# Account 156 subscribed!
# Account 157 subscribed!
# Account 158 subscribed!
# Account 159 subscribed!
# Account 160 subscribed!
# Account 161 subscribed!
# Account 162 subscribed!
# Account 163 subscribed!
# Account 164 subscribed!
# Account 165 subscribed!
# Account 166 subscribed!
# Account 167 subscribed!
# Account 168 subscribed!
# Account 169 subscribed!
# Account 170 subscribed!
# Account 171 subscribed!
# Account 172 subscribed!
# Account 173 subscribed!
# Account 174 subscribed!
# Account 175 subscribed!
# Account 176 subscribed!
# Account 177 subscribed!
# Account 178 subscribed!
# Account 179 subscribed!
# Account 180 subscribed!
# Account 181 subscribed!
# Account 182 subscribed!
# Account 183 subscribed!
# Account 184 subscribed!
# Account 185 subscribed!
# Account 186 subscribed!
# Account 187 subscribed!
# Account 188 subscribed!
# Account 189 subscribed!
# Account 190 subscribed!
# Account 191 subscribed!
# Account 192 subscribed!
# Account 193 subscribed!
# Account 194 subscribed!
# Account 195 subscribed!
# Account 196 subscribed!
# Account 197 subscribed!
# Account 198 subscribed!
# Account 199 subscribed!
# Account 200 subscribed!
# Account 201 subscribed!
# Account 202 subscribed!
# Account 203 subscribed!
# Account 204 subscribed!
# Account 205 subscribed!
# Account 206 subscribed!
# Account 207 subscribed!
# Account 208 subscribed!
# Account 209 subscribed!
# Account 210 subscribed!
# Account 211 subscribed!
# Account 212 subscribed!
# Account 213 subscribed!
# Account 214 subscribed!
# Account 215 subscribed!
# Account 216 subscribed!
# Account 217 subscribed!
# Account 218 subscribed!
# Account 219 subscribed!
# Account 220 subscribed!
# Account 221 subscribed!
# Account 222 subscribed!
# Account 223 subscribed!
# Account 224 subscribed!
# Account 225 subscribed!
# Account 226 subscribed!
# Account 227 subscribed!
# Account 228 subscribed!
# Account 229 subscribed!
# Account 230 subscribed!
# Account 231 subscribed!
# Account 232 subscribed!
# Account 233 subscribed!
# Account 234 subscribed!
# Account 235 subscribed!
# Account 236 subscribed!
# Account 237 subscribed!
# Account 238 subscribed!
# Account 239 subscribed!
# Account 240 subscribed!
# Account 241 subscribed!
# Account 242 subscribed!
# Account 243 subscribed!
# Account 244 subscribed!
# Account 245 subscribed!
# Account 246 subscribed!
# Account 247 subscribed!
# Account 248 subscribed!
# Account 249 subscribed!
# Account 250 subscribed!
# Account 251 subscribed!
# Account 252 subscribed!
# Account 253 subscribed!
# Account 254 subscribed!
# Account 255 subscribed!
# Account 256 subscribed!
# Account 257 subscribed!
# Account 258 subscribed!
# Account 259 subscribed!
# Account 260 subscribed!
# Account 261 subscribed!
# Account 262 subscribed!
# Account 263 subscribed!
# Account 264 subscribed!
# Account 265 subscribed!
# Account 266 subscribed!
# Account 267 subscribed!
# Account 268 subscribed!
# Account 269 subscribed!
# Account 270 subscribed!
# Account 271 subscribed!
# Account 272 subscribed!
# Account 273 subscribed!
# Account 274 subscribed!
# Account 275 subscribed!
# Account 276 subscribed!
# Account 277 subscribed!
# Account 278 subscribed!
# Account 279 subscribed!
# Account 280 subscribed!
# Account 281 subscribed!
# Account 282 subscribed!
# Account 283 subscribed!
# Account 284 subscribed!
# Account 285 subscribed!
# Account 286 subscribed!
# Account 287 subscribed!
# Account 288 subscribed!
# Account 289 subscribed!
# Account 290 subscribed!
# Account 291 subscribed!
# Account 292 subscribed!
# Account 293 subscribed!
# Account 294 subscribed!
# Account 295 subscribed!
# Account 296 subscribed!
# Account 297 subscribed!
# Account 298 subscribed!
# Account 299 subscribed!
# Account 300 subscribed!
# Account 301 subscribed!
# Account 302 subscribed!
# Account 303 subscribed!
# Account 304 subscribed!
# Account 305 subscribed!
# Account 306 subscribed!
# Account 307 subscribed!
# Account 308 subscribed!
# Account 309 subscribed!
# Account 310 subscribed!
# Account 311 subscribed!
# Account 312 subscribed!
# Account 313 subscribed!
# Account 314 subscribed!
# Account 315 subscribed!
# Account 316 subscribed!
# Account 317 subscribed!
# Account 318 subscribed!
# Account 319 subscribed!
# Account 320 subscribed!
# Account 321 subscribed!
# Account 322 subscribed!
# Account 323 subscribed!
# Account 324 subscribed!
# Account 325 subscribed!
# Account 326 subscribed!
# Account 327 subscribed!
# Account 328 subscribed!
# Account 329 subscribed!
# Account 330 subscribed!
# Account 331 subscribed!
# Account 332 subscribed!
# Account 333 subscribed!
# Account 334 subscribed!
# Account 335 subscribed!
# Account 336 subscribed!
# Account 337 subscribed!
# Account 338 subscribed!
# Account 339 subscribed!
# Account 340 subscribed!
# Account 341 subscribed!
# Account 342 subscribed!
# Account 343 subscribed!
# Account 344 subscribed!
# Account 345 subscribed!
# Account 346 subscribed!
# Account 347 subscribed!
# Account 348 subscribed!
# Account 349 subscribed!
# Account 350 subscribed!
# Account 351 subscribed!
# Account 352 subscribed!
# Account 353 subscribed!
# Account 354 subscribed!
# Account 355 subscribed!
# Account 356 subscribed!
# Account 357 subscribed!
# Account 358 subscribed!
# Account 359 subscribed!
# Account 360 subscribed!
# Account 361 subscribed!
# Account 362 subscribed!
# Account 363 subscribed!
# Account 364 subscribed!
# Account 365 subscribed!
# Account 366 subscribed!
# Account 367 subscribed!
# Account 368 subscribed!
# Account 369 subscribed!
# Account 370 subscribed!
# Account 371 subscribed!
# Account 372 subscribed!
# Account 373 subscribed!
# Account 374 subscribed!
# Account 375 subscribed!
# Account 376 subscribed!
# Account 377 subscribed!
# Account 378 subscribed!
# Account 379 subscribed!
# Account 380 subscribed!
# Account 381 subscribed!
# Account 382 subscribed!
# Account 383 subscribed!
# Account 384 subscribed!
# Account 385 subscribed!
# Account 386 subscribed!
# Account 387 subscribed!
# Account 388 subscribed!
# Account 389 subscribed!
# Account 390 subscribed!
# Account 391 subscribed!
# Account 392 subscribed!
# Account 393 subscribed!
# Account 394 subscribed!
# Account 395 subscribed!
# Account 396 subscribed!
# Account 397 subscribed!
# Account 398 subscribed!
# Account 399 subscribed!
# Account 400 subscribed!
# Account 401 subscribed!
# Account 402 subscribed!
# Account 403 subscribed!
# Account 404 subscribed!
# Account 405 subscribed!
# Account 406 subscribed!
# Account 407 subscribed!
# Account 408 subscribed!
# Account 409 subscribed!
# Account 410 subscribed!
# Account 411 subscribed!
# Account 412 subscribed!
# Account 413 subscribed!
# Account 414 subscribed!
# Account 415 subscribed!
# Account 416 subscribed!
# Account 417 subscribed!
# Account 418 subscribed!
# Account 419 subscribed!
# Account 420 subscribed!
# Account 421 subscribed!
# Account 422 subscribed!
# Account 423 subscribed!
# Account 424 subscribed!
# Account 425 subscribed!
# Account 426 subscribed!
# Account 427 subscribed!
# Account 428 subscribed!
# Account 429 subscribed!
# Account 430 subscribed!
# Account 431 subscribed!
# Account 432 subscribed!
# Account 433 subscribed!
# Account 434 subscribed!
# Account 435 subscribed!
# Account 436 subscribed!
# Account 437 subscribed!
# Account 438 subscribed!
# Account 439 subscribed!
# Account 440 subscribed!
# Account 441 subscribed!
# Account 442 subscribed!
# Account 443 subscribed!
# Account 444 subscribed!
# Account 445 subscribed!
# Account 446 subscribed!
# Account 447 subscribed!
# Account 448 subscribed!
# Account 449 subscribed!
# Account 450 subscribed!
# Account 451 subscribed!
# Account 452 subscribed!
# Account 453 subscribed!
# Account 454 subscribed!
# Account 455 subscribed!
# Account 456 subscribed!
# Account 457 subscribed!
# Account 458 subscribed!
# Account 459 subscribed!
# Account 460 subscribed!
# Account 461 subscribed!
# Account 462 subscribed!
# Account 463 subscribed!
# Account 464 subscribed!
# Account 465 subscribed!
# Account 466 subscribed!
# Account 467 subscribed!
# Account 468 subscribed!
# Account 469 subscribed!
# Account 470 subscribed!
# Account 471 subscribed!
# Account 472 subscribed!
# Account 473 subscribed!
# Account 474 subscribed!
# Account 475 subscribed!
# Account 476 subscribed!
# Account 477 subscribed!
# Account 478 subscribed!
# Account 479 subscribed!
# Account 480 subscribed!
# Account 481 subscribed!
# Account 482 subscribed!
# Account 483 subscribed!
# Account 484 subscribed!
# Account 485 subscribed!
# Account 486 subscribed!
# Account 487 subscribed!
# Account 488 subscribed!
# Account 489 subscribed!
# Account 490 subscribed!
# Account 491 subscribed!
# Account 492 subscribed!
# Account 493 subscribed!
# Account 494 subscribed!
# Account 495 subscribed!
# Account 496 subscribed!
# Account 497 subscribed!
# Account 498 subscribed!
# Account 499 subscribed!
# Account 500 subscribed!
# Account 501 subscribed!
# Account 502 subscribed!
# Account 503 subscribed!
# Account 504 subscribed!
# Account 505 subscribed!
# Account 506 subscribed!
# Account 507 subscribed!
# Account 508 subscribed!
# Account 509 subscribed!
# Account 510 subscribed!
# Account 511 subscribed!
# Account 512 subscribed!
# Account 513 subscribed!
# Account 514 subscribed!
# Account 515 subscribed!
# Account 516 subscribed!
# Account 517 subscribed!
# Account 518 subscribed!
# Account 519 subscribed!
# Account 520 subscribed!
# Account 521 subscribed!
# Account 522 subscribed!
# Account 523 subscribed!
# Account 524 subscribed!
# Account 525 subscribed!
# Account 526 subscribed!
# Account 527 subscribed!
# Account 528 subscribed!
# Account 529 subscribed!
# Account 530 subscribed!
# Account 531 subscribed!
# Account 532 subscribed!
# Account 533 subscribed!
# Account 534 subscribed!
# Account 535 subscribed!
# Account 536 subscribed!
# Account 537 subscribed!
# Account 538 subscribed!
# Account 539 subscribed!
# Account 540 subscribed!
# Account 541 subscribed!
# Account 542 subscribed!
# Account 543 subscribed!
# Account 544 subscribed!
# Account 545 subscribed!
# Account 546 subscribed!
# Account 547 subscribed!
# Account 548 subscribed!
# Account 549 subscribed!
# Account 550 subscribed!
# Account 551 subscribed!
# Account 552 subscribed!
# Account 553 subscribed!
# Account 554 subscribed!
# Account 555 subscribed!
# Account 556 subscribed!
# Account 557 subscribed!
# Account 558 subscribed!
# Account 559 subscribed!
# Account 560 subscribed!
# Account 561 subscribed!
# Account 563 subscribed!
# Account 564 subscribed!
# Account 565 subscribed!
# Account 566 subscribed!
# Account 567 subscribed!
# Account 568 subscribed!
# Account 569 subscribed!
# Account 570 subscribed!
# Account 571 subscribed!
# Account 572 subscribed!
# Account 573 subscribed!
# Account 574 subscribed!
# Account 575 subscribed!
# Account 576 subscribed!
# Account 577 subscribed!
# Account 578 subscribed!
# Account 579 subscribed!
# Account 580 subscribed!
# Account 581 subscribed!
# Account 582 subscribed!
# Account 583 subscribed!
# Account 584 subscribed!
# Account 585 subscribed!
# Account 586 subscribed!
# Account 598 subscribed!
# Account 599 subscribed!
# Account 602 subscribed!
# Account 603 subscribed!
# Account 604 subscribed!
# Account 605 subscribed!
# Account 606 subscribed!
# Account 607 subscribed!
# Account 608 subscribed!
# Account 609 subscribed!
# Account 610 subscribed!
# Account 611 subscribed!
# Account 612 subscribed!
# Account 613 subscribed!
# Account 614 subscribed!
# Account 615 subscribed!
# Account 616 subscribed!
# Account 617 subscribed!
# Account 618 subscribed!
# Account 619 subscribed!
# Account 620 subscribed!
# Account 621 subscribed!
# Account 622 subscribed!
# Account 623 subscribed!
# Account 624 subscribed!
# Account 625 subscribed!
# Account 626 subscribed!
# Account 627 subscribed!
# Account 628 subscribed!
# Account 629 subscribed!
# Account 630 subscribed!
# Account 631 subscribed!
# Account 633 subscribed!
# Account 634 subscribed!
# Account 635 subscribed!
# Account 636 subscribed!
# Account 637 subscribed!
# Account 638 subscribed!
# Account 639 subscribed!
# Account 640 subscribed!
# Account 641 subscribed!
# Account 642 subscribed!
# Account 643 subscribed!
# Account 644 subscribed!
# Account 645 subscribed!
# Account 646 subscribed!
# Account 647 subscribed!
# Account 648 subscribed!
# Account 649 subscribed!
# Account 650 subscribed!
# Account 651 subscribed!
# Account 652 subscribed!
# Account 653 subscribed!
# Account 654 subscribed!
# Account 655 subscribed!
# Account 656 subscribed!
# Account 657 subscribed!
# Account 658 subscribed!
# Account 659 subscribed!
# Account 660 subscribed!
# Account 661 subscribed!
# Account 662 subscribed!
# Account 663 subscribed!
# Account 664 subscribed!
# Account 665 subscribed!
# Account 666 subscribed!
# Account 667 subscribed!
# Account 668 subscribed!
# Account 669 subscribed!
# Account 670 subscribed!
# Account 671 subscribed!
# Account 672 subscribed!
# Account 673 subscribed!
# Account 674 subscribed!
# Account 675 subscribed!
# Account 676 subscribed!
# Account 677 subscribed!
# Account 678 subscribed!
# Account 679 subscribed!
# Account 680 subscribed!
# Account 681 subscribed!
# Account 682 subscribed!
# Account 683 subscribed!
# Account 684 subscribed!
# Account 685 subscribed!
# Account 686 subscribed!
# Account 687 subscribed!
# Account 688 subscribed!
# Account 689 subscribed!
# Account 690 subscribed!
# Account 691 subscribed!
# Account 692 subscribed!
# Account 693 subscribed!
# Account 694 subscribed!
# Account 695 subscribed!
# Account 696 subscribed!
# Account 697 subscribed!
# Account 698 subscribed!
# Account 699 subscribed!
# Account 700 subscribed!
# Account 701 subscribed!
# Account 702 subscribed!
# Account 703 subscribed!
# Account 704 subscribed!
# Account 705 subscribed!
# Account 706 subscribed!
# Account 707 subscribed!
# Account 708 subscribed!
# Account 709 subscribed!
# Account 710 subscribed!
# Account 711 subscribed!
# Account 712 subscribed!
# Account 713 subscribed!
# Account 714 subscribed!
# Account 715 subscribed!
# Account 716 subscribed!
# Account 717 subscribed!
# Account 718 subscribed!
# Account 719 subscribed!
# Account 720 subscribed!
# Account 721 subscribed!
# Account 722 subscribed!
# Account 723 subscribed!
# Account 724 subscribed!
# Account 725 subscribed!
# Account 726 subscribed!
# Account 727 subscribed!
# Account 728 subscribed!
# Account 729 subscribed!
# Account 730 subscribed!
# Account 731 subscribed!
# Account 732 subscribed!
# Account 733 subscribed!
# Account 734 subscribed!
# Account 735 subscribed!
# Account 736 subscribed!
# Account 737 subscribed!
# Account 738 subscribed!
# Account 739 subscribed!
# Account 740 subscribed!
# Account 741 subscribed!
# Account 742 subscribed!
# Account 743 subscribed!
# Account 744 subscribed!
# Account 745 subscribed!
# Account 746 subscribed!
# Account 747 subscribed!
# Account 748 subscribed!
# Account 749 subscribed!
# Account 750 subscribed!
# Account 751 subscribed!
# Account 752 subscribed!
# Account 753 subscribed!
# Account 754 subscribed!
# Account 755 subscribed!
# Account 756 subscribed!
# Account 757 subscribed!
# Account 758 subscribed!
# Account 759 subscribed!
# Account 760 subscribed!
# Account 761 subscribed!
# Account 762 subscribed!
# Account 763 subscribed!
# Account 764 subscribed!
# Account 765 subscribed!
# Account 766 subscribed!
# Account 767 subscribed!
# Account 768 subscribed!
# Account 769 subscribed!
# Account 770 subscribed!
# Account 771 subscribed!
# Account 772 subscribed!
# Account 773 subscribed!
# Account 774 subscribed!
# Account 775 subscribed!
# Account 776 subscribed!
# Account 777 subscribed!
# Account 778 subscribed!
# Account 779 subscribed!
# Account 780 subscribed!
# Account 781 subscribed!
# Account 782 subscribed!
# Account 783 subscribed!
# Account 784 subscribed!
# Account 785 subscribed!
# Account 786 subscribed!
# Account 787 subscribed!
# Account 788 subscribed!
# Account 789 subscribed!
# Account 790 subscribed!
# Account 791 subscribed!
# Account 792 subscribed!
# Account 793 subscribed!
# Account 794 subscribed!
# Account 795 subscribed!
# Account 796 subscribed!
# Account 797 subscribed!
# Account 798 subscribed!
# Account 799 subscribed!
# Account 800 subscribed!
# Account 801 subscribed!
# Account 802 subscribed!
# Account 803 subscribed!
# Account 804 subscribed!
# Account 805 subscribed!
# Account 806 subscribed!
# Account 807 subscribed!
# Account 808 subscribed!
# Account 809 subscribed!
# Account 810 subscribed!
# Account 811 subscribed!
# Account 812 subscribed!
# Account 813 subscribed!
# Account 814 subscribed!
